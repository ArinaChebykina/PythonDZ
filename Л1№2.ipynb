# %%
import numpy as np
import decimal
import matplotlib.pyplot as plt
x = np.around(np.arange(-7, 7.01, 0.01), decimals=4)
plt.ylim (-7, 10)
plt.grid(True)
plt.xticks(np.arange(-7, 8))
plt.plot(x, (x**3-4)/(x-1)**3)
plt.show()
#ОТвет:точки локального экстремума -2 и 2
