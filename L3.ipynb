# %%
#L3 Ф1
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-10, 10.01, 0.01)
t = np.arange(-10, 11, 1)
y = x**2

plt.plot(x, y, '--', lw = 2, c = 'b')
plt.plot(t, t*t, 'd', c = 'pink', ms = 10, mec = "black", mew = 1.5 )
plt.xlabel(r'$x$', fontsize=14)
plt.ylabel(r'$f(x)$', fontsize=14)
plt.title(r'$f(x)=x^2$', fontsize=16)
plt.grid()

plt.show()

# %%
#L3 СФ1
f = open('СФ1.txt','r')
l = []
n = 0
 
for i in f:
    l.append(i.rstrip())

k = l.pop(0)
a = list(map(int, l))
m = max(a)

while m % 10 == 0:
    n += 1
    m = m//10

result = open('result.txt', 'w+')
result.write(str(n))

f.close()
result.close()

# %%
#L3 СФ8
file = open('СФ8.txt', 'r')
l = []
n = 0
t = 0
 
for i in file:
    l.append(i.rstrip())

k = l.pop(0)
a = list(map(int, l))
max = max(a)
min = min(a)
for i in range(len(a)):
    if a[i] == max:
        n = i
        b = a[i]
    if a[i] == min:
        t = i
        c = a[i]
a[n] = c
a[t] = b

result = open('result.txt', 'w')
for i in range(len(a)):
    result.write(str(a[i])+'\n')

file.close()
result.close()
